# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\Redal\OneDrive\Desktop\Travel euro\FashionDataset.csv")
print(df)


df.columns
# Out:
#        Unnamed: 0    BrandName  \
# 0               0         life
# 1               1         only
# 2               2      fratini
# 3               3  zink london
# 4               4         life
# ...           ...          ...
# 30753          21    swarovski
# 30754          22          Nan
# 30755          23       jewelz
# 30756          24      estelle
# 30757          25      estelle
#
#                                                  Deatils  \
# 0      solid cotton blend collar neck womens a-line d...
# 1      polyester peter pan collar womens blouson dres...
# 2      solid polyester blend wide neck womens regular...
# 3      stripes polyester sweetheart neck womens dress...
# 4      regular fit regular length denim womens jeans ...
# ...                                                  ...
# 30753            crystal stylish womens rodhium earrings
# 30754                                                Nan
# 30755                 ethnic gold plated jhumki earrings
# ...

# %%
print(df.head(20))
# Out:
#       BrandName                                            Deatils  \
# 0          life  solid cotton blend collar neck womens a-line d...
# 1          only  polyester peter pan collar womens blouson dres...
# 2       fratini  solid polyester blend wide neck womens regular...
# 3   zink london  stripes polyester sweetheart neck womens dress...
# 4          life  regular fit regular length denim womens jeans ...
# 5         kraus  wide ankle length cotton womens jeans - light ...
# 6          life  printed cotton blend collared womens regular d...
# 7       fratini  embroidered wide neck polyester womens regular...
# 8          rare  floral polyester v neck womens flared dress - ...
# 9          rare  checks cotton boat neck womens regular top - b...
# 10         life  solid square neck cotton womens regular dress ...
# 11         life  regular fit regular length denim womens jeans ...
# 12         life  printed blended round neck womens shift dress ...
# ...

# %%
df
# Out:
#          BrandName                                            Deatils  \
# 0             life  solid cotton blend collar neck womens a-line d...
# 1             only  polyester peter pan collar womens blouson dres...
# 2          fratini  solid polyester blend wide neck womens regular...
# 3      zink london  stripes polyester sweetheart neck womens dress...
# 4             life  regular fit regular length denim womens jeans ...
# ...            ...                                                ...
# 30753    swarovski            crystal stylish womens rodhium earrings
# 30754          Nan                                                Nan
# 30755       jewelz                 ethnic gold plated jhumki earrings
# 30756      estelle  womens gold plated double line fancy white and...
# 30757      estelle  womens gold plated bridge designer mangalsutra...
#
#                                          Sizes       MRP SellPrice Discount  \
# ...

# %%
df.columns
# Out:
# Index(['BrandName', 'Deatils', 'Sizes', 'MRP', 'SellPrice', 'Discount',
#        'Category'],
#       dtype='object')

# %%
df.rename(columns= {"Deatils" : "Details"})
df.columns
# Out:
# Index(['BrandName', 'Details', 'Sizes', 'MRP', 'SellPrice', 'Discount',
#        'Category'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# np.int64(2827)

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#                 BrandName                                            Details  \
# 0                    life  solid cotton blend collar neck womens a-line d...
# 1                    only  polyester peter pan collar womens blouson dres...
# 2                 fratini  solid polyester blend wide neck womens regular...
# 3             zink london  stripes polyester sweetheart neck womens dress...
# 4                    life  regular fit regular length denim womens jeans ...
# ...                   ...                                                ...
# 30752  shaya by caratlane               the wing woman clover charm necklace
# 30753           swarovski            crystal stylish womens rodhium earrings
# 30755              jewelz                 ethnic gold plated jhumki earrings
# 30756             estelle  womens gold plated double line fancy white and...
# 30757             estelle  womens gold plated bridge designer mangalsutra...
#
# ...

# %%
df.reset_index()
# Out:
#        index           BrandName  \
# 0          0                life
# 1          1                only
# 2          2             fratini
# 3          3         zink london
# 4          4                life
# ...      ...                 ...
# 27926  30752  shaya by caratlane
# 27927  30753           swarovski
# 27928  30755              jewelz
# 27929  30756             estelle
# 27930  30757             estelle
#
#                                                  Details  \
# 0      solid cotton blend collar neck womens a-line d...
# 1      polyester peter pan collar womens blouson dres...
# 2      solid polyester blend wide neck womens regular...
# 3      stripes polyester sweetheart neck womens dress...
# 4      regular fit regular length denim womens jeans ...
# ...                                                  ...
# 27926               the wing woman clover charm necklace
# 27927            crystal stylish womens rodhium earrings
# ...

# %%
df1= df.reset_index().drop(columns= "index")

# %%
df1
# Out:
#                 BrandName                                            Details  \
# 0                    life  solid cotton blend collar neck womens a-line d...
# 1                    only  polyester peter pan collar womens blouson dres...
# 2                 fratini  solid polyester blend wide neck womens regular...
# 3             zink london  stripes polyester sweetheart neck womens dress...
# 4                    life  regular fit regular length denim womens jeans ...
# ...                   ...                                                ...
# 27926  shaya by caratlane               the wing woman clover charm necklace
# 27927           swarovski            crystal stylish womens rodhium earrings
# 27928              jewelz                 ethnic gold plated jhumki earrings
# 27929             estelle  womens gold plated double line fancy white and...
# 27930             estelle  womens gold plated bridge designer mangalsutra...
#
# ...

# %%
df1.isna().sum()
# Out:
# BrandName    0
# Details      0
# Sizes        0
# MRP          0
# SellPrice    0
# Discount     0
# Category     0
# dtype: int64

# %%
df1.dropna(inplace=True)

# %%
df1.isna().sum()
# Out:
# BrandName    0
# Details      0
# Sizes        0
# MRP          0
# SellPrice    0
# Discount     0
# Category     0
# dtype: int64

# %%
df1["BrandName"].apply(lambda x: x.capitalize())
# Out:
# 0                      Life
# 1                      Only
# 2                   Fratini
# 3               Zink london
# 4                      Life
#                 ...
# 27926    Shaya by caratlane
# 27927             Swarovski
# 27928                Jewelz
# 27929               Estelle
# 27930               Estelle
# Name: BrandName, Length: 27931, dtype: object

# %%
df1["Details"].apply(lambda x: x.capitalize())
# Out:
# 0        Solid cotton blend collar neck womens a-line d...
# 1        Polyester peter pan collar womens blouson dres...
# 2        Solid polyester blend wide neck womens regular...
# 3        Stripes polyester sweetheart neck womens dress...
# 4        Regular fit regular length denim womens jeans ...
#                                ...
# 27926                 The wing woman clover charm necklace
# 27927              Crystal stylish womens rodhium earrings
# 27928                   Ethnic gold plated jhumki earrings
# 27929    Womens gold plated double line fancy white and...
# 27930    Womens gold plated bridge designer mangalsutra...
# Name: Details, Length: 27931, dtype: object

# %%
df1["Sizes"][27929]
# Out:
# 'Nan'

# %%
df1["Sizes"] = df1["Sizes"].replace("Nan", "NA VALUED")

# %%
df1
# Out:
#                 BrandName                                            Details  \
# 0                    life  solid cotton blend collar neck womens a-line d...
# 1                    only  polyester peter pan collar womens blouson dres...
# 2                 fratini  solid polyester blend wide neck womens regular...
# 3             zink london  stripes polyester sweetheart neck womens dress...
# 4                    life  regular fit regular length denim womens jeans ...
# ...                   ...                                                ...
# 27926  shaya by caratlane               the wing woman clover charm necklace
# 27927           swarovski            crystal stylish womens rodhium earrings
# 27928              jewelz                 ethnic gold plated jhumki earrings
# 27929             estelle  womens gold plated double line fancy white and...
# 27930             estelle  womens gold plated bridge designer mangalsutra...
#
# ...

# %%
df1[df1["Sizes"] != "NA VALUED"]
# Out:
#             BrandName                                            Details  \
# 0                life  solid cotton blend collar neck womens a-line d...
# 1                only  polyester peter pan collar womens blouson dres...
# 2             fratini  solid polyester blend wide neck womens regular...
# 3         zink london  stripes polyester sweetheart neck womens dress...
# 4                life  regular fit regular length denim womens jeans ...
# ...               ...                                                ...
# 24344     swiss eagle                     womens analogue metallic watch
# 24731  lawman watches  womens rose gold dial stainless steel analogue...
# 25791  lawman watches  womens silver dial stainless steel analogue wa...
# 26028         miu miu                              eau de parfum - 50 ml
# 26078         miu miu                              eau de parfum - 30 ml
#
#                                          Sizes        MRP SellPrice Discount  \
# ...

# %%
df1["Discount]"] = df1["Discount"].replace("Nan", "No Discosunt")

# %%
df1
# Out:
#                 BrandName                                            Details  \
# 0                    life  solid cotton blend collar neck womens a-line d...
# 1                    only  polyester peter pan collar womens blouson dres...
# 2                 fratini  solid polyester blend wide neck womens regular...
# 3             zink london  stripes polyester sweetheart neck womens dress...
# 4                    life  regular fit regular length denim womens jeans ...
# ...                   ...                                                ...
# 27926  shaya by caratlane               the wing woman clover charm necklace
# 27927           swarovski            crystal stylish womens rodhium earrings
# 27928              jewelz                 ethnic gold plated jhumki earrings
# 27929             estelle  womens gold plated double line fancy white and...
# 27930             estelle  womens gold plated bridge designer mangalsutra...
#
# ...

# %%
df1["Sizes"]= df1["Sizes"].replace("NA VALUED", "Size:Error Size")

# %%
df1
# Out:
#                 BrandName                                            Details  \
# 0                    life  solid cotton blend collar neck womens a-line d...
# 1                    only  polyester peter pan collar womens blouson dres...
# 2                 fratini  solid polyester blend wide neck womens regular...
# 3             zink london  stripes polyester sweetheart neck womens dress...
# 4                    life  regular fit regular length denim womens jeans ...
# ...                   ...                                                ...
# 27926  shaya by caratlane               the wing woman clover charm necklace
# 27927           swarovski            crystal stylish womens rodhium earrings
# 27928              jewelz                 ethnic gold plated jhumki earrings
# 27929             estelle  womens gold plated double line fancy white and...
# 27930             estelle  womens gold plated bridge designer mangalsutra...
#
# ...

# %%
df1.to_excel("Cleaned_data.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 df1.to_excel("Cleaned_data.xlsx")
#
# File c:\Users\Redal\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %%
df1.to_csv("FashionDataset_Cleaned.csv", index= False)

# %%
df1.to_excel("Cleaned_FashionDataset.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 df1.to_excel("Cleaned_FashionDataset.xlsx")
#
# File c:\Users\Redal\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %%
pd.read_csv("FashionDataset_Cleaned.csv")
# Out:
#                 BrandName                                            Details  \
# 0                    life  solid cotton blend collar neck womens a-line d...
# 1                    only  polyester peter pan collar womens blouson dres...
# 2                 fratini  solid polyester blend wide neck womens regular...
# 3             zink london  stripes polyester sweetheart neck womens dress...
# 4                    life  regular fit regular length denim womens jeans ...
# ...                   ...                                                ...
# 27926  shaya by caratlane               the wing woman clover charm necklace
# 27927           swarovski            crystal stylish womens rodhium earrings
# 27928              jewelz                 ethnic gold plated jhumki earrings
# 27929             estelle  womens gold plated double line fancy white and...
# 27930             estelle  womens gold plated bridge designer mangalsutra...
#
# ...
